# %% [markdown]
# <a href="https://colab.research.google.com/github/farzanehnia/Finance/blob/main/Finance_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas_datareader
pandas_datareader.__version__  # Should show 0.10.0
# Out:
# '0.10.0'

# %%
from pandas_datareader import data, wb
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import datetime as dt
# %matplotlib inline

# %% [markdown]
# Using datareader we get the stock information of the following banks:
# Bank of America,
# CitiGroup,
# Goldman Sachs,
# JPMorgan Chase,
# Morgan Stanley,
# Wells Fargo
#
# ### Figure stock data from Jan 1st 2006 to Jan 1st 2016 to a seperate dataframe.

# %%
start = dt.datetime(2006, 1, 1)
end = dt.datetime(2016, 1, 1)

# %%
BAC = data.DataReader('BAC', 'yahoo', start, end)
#df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')

C = data.DataReader('C', 'yahoo', start, end)
GS = data.DataReader('GS', 'yahoo', start, end)
JPM = data.DataReader('JPM', 'yahoo', start, end)
MS = data.DataReader('MS', 'yahoo', start, end)
WFC = data.DataReader('WFC', 'yahoo', start, end)

# %%
MS.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  35.558975
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  35.583351
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  35.680923
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  35.717518
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  36.095608

# %% [markdown]
# ### List of tickers in alphabetical order

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# Use pd.concat ti make single df
# key arguments = tickers list

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1, keys=tickers) #axis=1 columns

# %%
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.584064
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.227390
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.270195
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.220264
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.241665
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.584064  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.227390  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.270195  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# Max close price for each bank's stock

# %%
for tick in tickers:
  print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %% [markdown]
# ##The pandorable way:

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max() #level is 1
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ## Create a new df with returns

# %%
returns = pd.DataFrame()

# %% [markdown]
# We can use pct_change() method on close col to

# %%
for tick in tickers:
  returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %% [markdown]
# Pairplot using seaborn of returns dataframe
#
# We can see the City group (here ms) is particular due to 2008 market crash.

# %%
import seaborn as sns
sns.pairplot(returns[1:], diag_kind='kde') #diag_kind{‘auto’, ‘hist’, ‘kde’, None}

# %% [markdown]
# Worst and best single day returns of the stocks?

# %%
#returns['BAC Return'].argmin()
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# A lot happened on 20th of Jan 2008. Obama's inaguaration day. The 21st was the best day for JPM!
#
# For Citygroup the month of May was their worst and best returns.
# (They had a reverse stock split)

# %% [markdown]
# Standard deviation is a measure of riskyness of a stock.
# over the whole period and over one specific year.

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# Distribution plot of MS for 2015 using seaborn

# %%
sns.distplot(returns['MS Return'].loc['2015-01-01':'2015-12-31'], bins=50, color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(returns['C Return'].loc['2008-01-01':'2008-12-31'], color='red', bins=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
#matplotlib inline

#Optional plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
  bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1, level='Stock Info').plot()

# %%
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.express as px

# %%
bank_stocks.xs(key='Close',axis=1, level='Stock Info').iplot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="25343f7b-279a-43fb-9079-bd1964361d6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='MA 30') # In older pandas version the ix was used, now it is replaced by loc and iloc.
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(),annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(),annot=True)

# %%
close_corr = bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
close_corr.iplot(kind='heatmap', colorscale='rdylgn') #rdylbu
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3ff67b70-d967-4672-ac20-a07bbe48b44d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac15 = BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="be4b333d-be0f-4387-9cb5-6affd68495e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma', periods=[10,20,50]) #study='boll'
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bfc0c7ca-150e-430e-88e9-e9dd8ddceb20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
